# %% [markdown]
# # Lý thuyết
#
# Cho $X$ có phân phối xác suất với tham số $\mu$ và $\sigma$ như sau
#
# $$P(X=x|\mu, \sigma^2) = \frac{1}{\sqrt{2\pi}\sigma} e^{-\frac{(x - \mu)^2}{2\sigma^2}}$$
#
# 1. Tính hàm likelihood cho phân bố trên khi $X$ nhận các quan sát $X_1, X_2, ..., X_n$

# %% [markdown]
# ![](https://i.imgur.com/5LFwv1k.jpg)

# %% [markdown]
# 2. Tính hàm log likelihood của hàm số trên.

# %% [markdown]
# ![](https://i.imgur.com/0KOLiBQ.jpg)

# %% [markdown]
# ![](https://i.imgur.com/FMbQ6Va.jpeg)

# %% [markdown]
# 3. Sử dụng Maximum Likelihood Estimate để tìm ra ước lượng tốt nhất cho các tham số $\hat{\mu}$ và $\hat{\sigma}$

# %% [markdown]
# ![](https://i.imgur.com/WU8W2wj.jpeg)

# %% [markdown]
# ![](https://i.imgur.com/hdE4KMP.jpeg)

# %% [markdown]
# Cho $X$ là sự kiện tung đồng xu $n$ lần với kết quả nhận được là $n_H$ mặt head, còn lại là mặt tail.
#
# Giả sử xác suất nhận được mặt head là:
# $0 \leq \theta \leq 1$.
# 4. Tính hàm likelihood của xác suất.

# %% [markdown]
# ![](https://i.imgur.com/hdE4KMP.jpeg)

# %% [markdown]
# 5. Sử dụng phương pháp Maximum Likelihood để ước lượng giá trị $\hat{\theta}$ hợp lý nhất.

# %% [markdown]
# ![](https://i.imgur.com/hdE4KMP.jpeg)

# %% [markdown]
# ![](https://i.imgur.com/qfR8lLc.jpeg)

# %% [markdown]
# Cho $X$ có phân phối xác suất với tham số $\lambda$ như sau
# $$P(X=x|\lambda) = \frac{\lambda^x e^{-\lambda}}{x!} \qquad \text{$x=0,1, 2,...n, \lambda > 0$}$$
# 6. Tính hàm likelihood

# %% [markdown]
# ![](https://i.imgur.com/jRmQ4Ce.jpeg)

# %% [markdown]
# 7. Sử dụng phương pháp Maximum Likelihood để ước lượng $\hat{\lambda}$.

# %% [markdown]
# ![](https://i.imgur.com/wbwSA9M.jpeg)

# %% [markdown]
# ![](https://i.imgur.com/pJGgR5S.jpeg)

# %% [markdown]
# 9. Tìm ước lượng MLE của $\lambda$ nếu chỉ tồn tại duy nhất xác suất $P(X=4)$.

# %% [markdown]
# ![](https://i.imgur.com/pJGgR5S.jpeg)

# %% [markdown]
# 10. Tìm ước lượng MLE của $\theta$ cho hàm phân bố xác xuất sau:
# $$P(X=x|\theta) = \frac{2\theta^2}{x^3}$$
# Biết rằng $ 0 \leq \theta \leq x \leq \infty$

# %% [markdown]
# ![](https://i.imgur.com/v9oZT45.jpeg)
